# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nasta\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nasta\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nasta\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests

# %%
data2 = pd.read_excel(r"C:\Users\nasta\OneDrive\Документы\hw-03-MarchenkovaAnastasya\first_stat.xlsx")
data2
data1 = pd.read_excel(r"C:\Users\nasta\OneDrive\Документы\hw-03-MarchenkovaAnastasya\second_stat.xlsx")
data1
# Out:
#               Таблица аналитическая  Браки в 2023 (на тыс. населения)  \
# 0              Российская Федерация                               6.5
# 1     Центральный федеральный округ                               6.5
# 2              Белгородская область                               6.7
# 3                  Брянская область                               6.0
# 4              Владимирская область                               6.1
# ..                              ...                               ...
# 91                 Амурская область                               7.8
# 92              Магаданская область                               7.6
# 93              Сахалинская область                               8.3
# 94     Еврейская автономная область                               7.6
# 95              Чукотский авт.округ                               6.1
#
#     Браки в 2022 (на тыс. населения)  2023 г. в  %  к 2022 г.   \
# 0                                7.2                      90.3
# 1                                7.4                      87.8
# 2                                7.4                      90.5
# 3                                6.4                      93.8
# 4                                6.6                      92.4
# ..                               ...                       ...
# 91                               9.9                      78.8
# 92                               9.2                      82.6
# 93                              10.0                      83.0
# 94                               9.0                      84.4
# 95                               8.8                      69.3
#
#     Разводы в 2023 (на тыс. населения)  Разводы в 2022 (на тыс. населения)  \
# 0                                  4.7                                 4.7
# 1                                  4.2                                 4.2
# 2                                  4.2                                 4.3
# 3                                  4.7                                 4.7
# 4                                  4.2                                 4.4
# ..                                 ...                                 ...
# 91                                 6.5                                 6.3
# 92                                 5.6                                 5.1
# 93                                 6.1                                 5.4
# 94                                 6.6                                 7.0
# 95                                 4.7                                 4.5
#
#     2023 г. в  %  к 2022 г. .1
# 0                   100.000000
# 1                   100.000000
# 2                    97.674419
# 3                   100.000000
# 4                    95.454545
# ..                         ...
# 91                  103.174603
# 92                  109.803922
# 93                  112.962963
# 94                   94.285714
# 95                  104.444444
#
# [96 rows x 7 columns]

# %%
data1 = data1.rename(columns={'Таблица аналитическая': 'Округ'})
data2 = data2.rename(columns={'Таблица аналитическая': 'Округ'})
data1
# Out:
#                               Округ  Браки в 2023 (на тыс. населения)  \
# 0              Российская Федерация                               6.5
# 1     Центральный федеральный округ                               6.5
# 2              Белгородская область                               6.7
# 3                  Брянская область                               6.0
# 4              Владимирская область                               6.1
# ..                              ...                               ...
# 91                 Амурская область                               7.8
# 92              Магаданская область                               7.6
# 93              Сахалинская область                               8.3
# 94     Еврейская автономная область                               7.6
# 95              Чукотский авт.округ                               6.1
#
#     Браки в 2022 (на тыс. населения)  2023 г. в  %  к 2022 г.   \
# 0                                7.2                      90.3
# 1                                7.4                      87.8
# 2                                7.4                      90.5
# 3                                6.4                      93.8
# 4                                6.6                      92.4
# ..                               ...                       ...
# 91                               9.9                      78.8
# 92                               9.2                      82.6
# 93                              10.0                      83.0
# 94                               9.0                      84.4
# 95                               8.8                      69.3
#
#     Разводы в 2023 (на тыс. населения)  Разводы в 2022 (на тыс. населения)  \
# 0                                  4.7                                 4.7
# 1                                  4.2                                 4.2
# 2                                  4.2                                 4.3
# 3                                  4.7                                 4.7
# 4                                  4.2                                 4.4
# ..                                 ...                                 ...
# 91                                 6.5                                 6.3
# 92                                 5.6                                 5.1
# 93                                 6.1                                 5.4
# 94                                 6.6                                 7.0
# 95                                 4.7                                 4.5
#
#     2023 г. в  %  к 2022 г. .1
# 0                   100.000000
# 1                   100.000000
# 2                    97.674419
# 3                   100.000000
# 4                    95.454545
# ..                         ...
# 91                  103.174603
# 92                  109.803922
# 93                  112.962963
# 94                   94.285714
# 95                  104.444444
#
# [96 rows x 7 columns]

# %% [markdown]
# Решейпинг массива

# %%
data_old = pd.merge(data1, data2, on='Округ')
data
data = data_old.rename(columns={'Родившиеся в 2023 (на тыс. населения)': 2023, 'Родившиеся в 2022 (на тыс. населения)': 2022}) #переименовываю, чтобы при мелте в столбце год был только год, без "Родившиеся на тыс.человек"
data
# Out:
#                               Округ  Браки в 2023 (на тыс. населения)  \
# 0              Российская Федерация                               6.5
# 1     Центральный федеральный округ                               6.5
# 2              Белгородская область                               6.7
# 3                  Брянская область                               6.0
# 4              Владимирская область                               6.1
# ..                              ...                               ...
# 91                 Амурская область                               7.8
# 92              Магаданская область                               7.6
# 93              Сахалинская область                               8.3
# 94     Еврейская автономная область                               7.6
# 95              Чукотский авт.округ                               6.1
#
#     Браки в 2022 (на тыс. населения)  2023 г. в  %  к 2022 г.   \
# 0                                7.2                      90.3
# 1                                7.4                      87.8
# 2                                7.4                      90.5
# 3                                6.4                      93.8
# 4                                6.6                      92.4
# ..                               ...                       ...
# 91                               9.9                      78.8
# 92                               9.2                      82.6
# 93                              10.0                      83.0
# 94                               9.0                      84.4
# 95                               8.8                      69.3
#
#     Разводы в 2023 (на тыс. населения)  Разводы в 2022 (на тыс. населения)  \
# 0                                  4.7                                 4.7
# 1                                  4.2                                 4.2
# 2                                  4.2                                 4.3
# 3                                  4.7                                 4.7
# 4                                  4.2                                 4.4
# ..                                 ...                                 ...
# 91                                 6.5                                 6.3
# 92                                 5.6                                 5.1
# 93                                 6.1                                 5.4
# 94                                 6.6                                 7.0
# 95                                 4.7                                 4.5
#
#     2023 г. в  %  к 2022 г. .1  2023  2022  2023 г. в  %  к 2022 г.   \
# 0                   100.000000   8.7   8.9                      97.8
# 1                   100.000000   8.0   8.2                      97.6
# 2                    97.674419   6.6   7.1                      93.0
# 3                   100.000000   6.9   7.2                      95.8
# 4                    95.454545   6.4   6.6                      97.0
# ..                         ...   ...   ...                       ...
# 91                  103.174603   9.2   9.2                     100.0
# 92                  109.803922   8.2   8.7                      94.3
# 93                  112.962963  10.0  10.7                      93.5
# 94                   94.285714   9.1   9.6                      94.8
# 95                  104.444444  10.9  10.4                     104.8
#
#     Умершие в 2023 (на тыс. населения)  Умершие в 2022 (на тыс. населения)  \
# 0                                 12.0                                13.0
# 1                                 12.0                                13.2
# 2                                 13.4                                14.2
# 3                                 14.3                                15.7
# 4                                 15.4                                16.9
# ..                                 ...                                 ...
# 91                                14.0                                14.9
# 92                                12.1                                12.6
# 93                                13.4                                13.8
# 94                                14.3                                15.2
# 95                                10.0                                10.3
#
#     2023 г. в  %  к 2022 г. .1  Естественный прирост, убыль (-) в 2023 г.  \
# 0                         92.3                                       -3.3
# 1                         90.9                                       -4.0
# 2                         94.4                                       -6.8
# 3                         91.1                                       -7.4
# 4                         91.1                                       -9.0
# ..                         ...                                        ...
# 91                        94.0                                       -4.8
# 92                        96.0                                       -3.9
# 93                        97.1                                       -3.4
# 94                        94.1                                       -5.2
# 95                        97.1                                        0.9
#
#     Естественный прирост, убыль (-) в 2022 г.
# 0                                        -4.1
# 1                                        -5.0
# 2                                        -7.1
# 3                                        -8.5
# 4                                       -10.3
# ..                                        ...
# 91                                       -5.7
# 92                                       -3.9
# 93                                       -3.1
# 94                                       -5.6
# 95                                        0.1
#
# [96 rows x 15 columns]

# %%
data_quasilong = data.melt(id_vars = data.columns[0],
                         value_vars = data.columns[7:9],

                         var_name = 'Год',
                         value_name = 'Количество родившихся (на тыс. населения)')
data_quasilong
# Out:
#                                Округ   Год  \
# 0               Российская Федерация  2023
# 1      Центральный федеральный округ  2023
# 2               Белгородская область  2023
# 3                   Брянская область  2023
# 4               Владимирская область  2023
# ..                               ...   ...
# 187                 Амурская область  2022
# 188              Магаданская область  2022
# 189              Сахалинская область  2022
# 190     Еврейская автономная область  2022
# 191              Чукотский авт.округ  2022
#
#      Количество родившихся (на тыс. населения)
# 0                                          8.7
# 1                                          8.0
# 2                                          6.6
# 3                                          6.9
# 4                                          6.4
# ..                                         ...
# 187                                        9.2
# 188                                        8.7
# 189                                       10.7
# 190                                        9.6
# 191                                       10.4
#
# [192 rows x 3 columns]

# %% [markdown]
# Проанализируем рождаемость за 2023 год по федеральным округам

# %%
federal_districts = [
    "Центральный федеральный округ",
    "Северо-Западный федеральный округ",
    "Южный федеральный округ",
    "Северо-Кавказский федеральный округ",
    "Приволжский федеральный округ",
    "Уральский федеральный округ",
    "Сибирский федеральный округ",
    "Дальневосточный федеральный округ"
]
data_quasilong['Округ'] = data_quasilong['Округ'].astype(str)
data_quasilong['Год'] = data_quasilong['Год'].astype(int)
data_quasilong['Округ'] = data_quasilong['Округ'].str.strip()

data2023 = data_quasilong.loc[(data_quasilong['Год'] == 2023) & (data_quasilong['Округ'].isin(federal_districts))]
data2023
# Out:
#                                   Округ   Год  \
# 1         Центральный федеральный округ  2023
# 20    Северо-Западный федеральный округ  2023
# 33              Южный федеральный округ  2023
# 42  Северо-Кавказский федеральный округ  2023
# 50        Приволжский федеральный округ  2023
# 65          Уральский федеральный округ  2023
# 73          Сибирский федеральный округ  2023
# 84    Дальневосточный федеральный округ  2023
#
#     Количество родившихся (на тыс. населения)
# 1                                         8.0
# 20                                        7.8
# 33                                        8.3
# 42                                       12.3
# 50                                        8.1
# 65                                        9.6
# 73                                        8.9
# 84                                        9.7

# %%
data2023["Количество родившихся (на тыс. населения)"].describe()
# Out:
# count     8.000000
# mean      9.087500
# std       1.484624
# min       7.800000
# 25%       8.075000
# 50%       8.600000
# 75%       9.625000
# max      12.300000
# Name: Количество родившихся (на тыс. населения), dtype: float64

# %%
data2023["Количество родившихся (на тыс. населения)"].median()
# Out:
# 8.600000000000001

# %% [markdown]
# Построим ящик с усами

# %%
plt.boxplot(data2023["Количество родившихся (на тыс. населения)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19c49f4f090>,
#   <matplotlib.lines.Line2D at 0x19c5088ccd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x19c5088f1d0>,
#   <matplotlib.lines.Line2D at 0x19c50888f50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19c50884690>],
#  'medians': [<matplotlib.lines.Line2D at 0x19c50889710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19c50889f90>],
#  'means': []}

# %%
plt.xlabel('Количество родившихся (на тыс. населения)')
plt.ylabel('Количество значений')
plt.hist(data2023["Количество родившихся (на тыс. населения)"], color = 'blue', edgecolor = 'black',
         bins = int(5))
# Out:
# (array([4., 1., 2., 0., 1.]),
#  array([ 7.8,  8.7,  9.6, 10.5, 11.4, 12.3]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# На примере данных за 2023 год посмотрим, есть ли корреляция между количеством разводов и рождаемостью на тыс. населения в федеральных округах

# %%
data
# Out:
#                               Округ  Браки в 2023 (на тыс. населения)  \
# 0              Российская Федерация                               6.5
# 1     Центральный федеральный округ                               6.5
# 2              Белгородская область                               6.7
# 3                  Брянская область                               6.0
# 4              Владимирская область                               6.1
# ..                              ...                               ...
# 91                 Амурская область                               7.8
# 92              Магаданская область                               7.6
# 93              Сахалинская область                               8.3
# 94     Еврейская автономная область                               7.6
# 95              Чукотский авт.округ                               6.1
#
#     Браки в 2022 (на тыс. населения)  2023 г. в  %  к 2022 г.   \
# 0                                7.2                      90.3
# 1                                7.4                      87.8
# 2                                7.4                      90.5
# 3                                6.4                      93.8
# 4                                6.6                      92.4
# ..                               ...                       ...
# 91                               9.9                      78.8
# 92                               9.2                      82.6
# 93                              10.0                      83.0
# 94                               9.0                      84.4
# 95                               8.8                      69.3
#
#     Разводы в 2023 (на тыс. населения)  Разводы в 2022 (на тыс. населения)  \
# 0                                  4.7                                 4.7
# 1                                  4.2                                 4.2
# 2                                  4.2                                 4.3
# 3                                  4.7                                 4.7
# 4                                  4.2                                 4.4
# ..                                 ...                                 ...
# 91                                 6.5                                 6.3
# 92                                 5.6                                 5.1
# 93                                 6.1                                 5.4
# 94                                 6.6                                 7.0
# 95                                 4.7                                 4.5
#
#     2023 г. в  %  к 2022 г. .1  2023  2022  2023 г. в  %  к 2022 г.   \
# 0                   100.000000   8.7   8.9                      97.8
# 1                   100.000000   8.0   8.2                      97.6
# 2                    97.674419   6.6   7.1                      93.0
# 3                   100.000000   6.9   7.2                      95.8
# 4                    95.454545   6.4   6.6                      97.0
# ..                         ...   ...   ...                       ...
# 91                  103.174603   9.2   9.2                     100.0
# 92                  109.803922   8.2   8.7                      94.3
# 93                  112.962963  10.0  10.7                      93.5
# 94                   94.285714   9.1   9.6                      94.8
# 95                  104.444444  10.9  10.4                     104.8
#
#     Умершие в 2023 (на тыс. населения)  Умершие в 2022 (на тыс. населения)  \
# 0                                 12.0                                13.0
# 1                                 12.0                                13.2
# 2                                 13.4                                14.2
# 3                                 14.3                                15.7
# 4                                 15.4                                16.9
# ..                                 ...                                 ...
# 91                                14.0                                14.9
# 92                                12.1                                12.6
# 93                                13.4                                13.8
# 94                                14.3                                15.2
# 95                                10.0                                10.3
#
#     2023 г. в  %  к 2022 г. .1  Естественный прирост, убыль (-) в 2023 г.  \
# 0                         92.3                                       -3.3
# 1                         90.9                                       -4.0
# 2                         94.4                                       -6.8
# 3                         91.1                                       -7.4
# 4                         91.1                                       -9.0
# ..                         ...                                        ...
# 91                        94.0                                       -4.8
# 92                        96.0                                       -3.9
# 93                        97.1                                       -3.4
# 94                        94.1                                       -5.2
# 95                        97.1                                        0.9
#
#     Естественный прирост, убыль (-) в 2022 г.
# 0                                        -4.1
# 1                                        -5.0
# 2                                        -7.1
# 3                                        -8.5
# 4                                       -10.3
# ..                                        ...
# 91                                       -5.7
# 92                                       -3.9
# 93                                       -3.1
# 94                                       -5.6
# 95                                        0.1
#
# [96 rows x 15 columns]

# %%
data_new = data[["Округ", "Разводы в 2023 (на тыс. населения)", 2023]].copy()
data_new
data_new = data_new.rename(columns={2023: 'Родившиеся в 2023 (на тыс. населения)'})
data_new
# Out:
#                               Округ  Разводы в 2023 (на тыс. населения)  \
# 0              Российская Федерация                                 4.7
# 1     Центральный федеральный округ                                 4.2
# 2              Белгородская область                                 4.2
# 3                  Брянская область                                 4.7
# 4              Владимирская область                                 4.2
# ..                              ...                                 ...
# 91                 Амурская область                                 6.5
# 92              Магаданская область                                 5.6
# 93              Сахалинская область                                 6.1
# 94     Еврейская автономная область                                 6.6
# 95              Чукотский авт.округ                                 4.7
#
#     Родившиеся в 2023 (на тыс. населения)
# 0                                     8.7
# 1                                     8.0
# 2                                     6.6
# 3                                     6.9
# 4                                     6.4
# ..                                    ...
# 91                                    9.2
# 92                                    8.2
# 93                                   10.0
# 94                                    9.1
# 95                                   10.9
#
# [96 rows x 3 columns]

# %%
federal_districts = [
    "Центральный федеральный округ",
    "Северо-Западный федеральный округ",
    "Южный федеральный округ",
    "Северо-Кавказский федеральный округ",
    "Приволжский федеральный округ",
    "Уральский федеральный округ",
    "Сибирский федеральный округ",
    "Дальневосточный федеральный округ"
]
data_new['Округ'] = data_new['Округ'].astype(str)
data_new['Округ'] = data_new['Округ'].str.strip()
data_new = data_new.loc[(data_new['Округ'].isin(federal_districts))]
data_new
# Out:
#                                   Округ  Разводы в 2023 (на тыс. населения)  \
# 1         Центральный федеральный округ                                 4.2
# 20    Северо-Западный федеральный округ                                 4.8
# 33              Южный федеральный округ                                 4.8
# 42  Северо-Кавказский федеральный округ                                 5.4
# 50        Приволжский федеральный округ                                 4.2
# 65          Уральский федеральный округ                                 5.2
# 73          Сибирский федеральный округ                                 5.1
# 84    Дальневосточный федеральный округ                                 5.8
#
#     Родившиеся в 2023 (на тыс. населения)
# 1                                     8.0
# 20                                    7.8
# 33                                    8.3
# 42                                   12.3
# 50                                    8.1
# 65                                    9.6
# 73                                    8.9
# 84                                    9.7

# %%
plt.scatter(data_new["Разводы в 2023 (на тыс. населения)"],data_new["Родившиеся в 2023 (на тыс. населения)"])

# %% [markdown]
# Как видно по диаграмме рассеивания, корреляции нет
